# %%
a=11
b=5

# %%
a+b
# Out:
# 16

# %%
a-b
# Out:
# 6

# %%
a*b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
a%b
# Out:
# 1

# %%
c=3

# %%
a==c# is a equal to c
# Out:
# False

# %%
a!=c
# Out:
# True

# %%
a=5
b=5

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
b1=True
b2=False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a=45

# %%
a+=4

# %%
a
# Out:
# 49

# %%
a-=4

# %%
a
# Out:
# 41
