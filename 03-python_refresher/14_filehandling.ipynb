# %%
f=open("text.txt","r")

# %%
f.read()
# Out:
# 'Roshan\nis \ngood \nEngineer'

# %%
s="This is a nice way to learn Data science"

# %%
f.close()

# %%
f=open("Roshan.txt","w")

# %%
f.write(s)
# Out:
# 40

# %%
f.close()
