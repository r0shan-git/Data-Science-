# %%
a=input("Enter the value of a") #by default user input as string
# Out:
# Enter the value of a 45

# %%
 a
# Out:
# '45'

# %%
b=input("Enter the value of b")
# Out:
# Enter the value of b 6

# %%
b
# Out:
# '6'

# %%
a +b
# Out:
# '456'

# %%
int(a)+int(b)
# Out:
# 51

# %%
c=input()
# Out:
#  67

# %%
c
# Out:
# '67'
