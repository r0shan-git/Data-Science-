# %%
code=200

# %%
match code:
  case 200:
      print("Response ok")
      print("Good job !")
  case 400:
      print("Bad Response")
  case 404:
      print("Not found")
print("End of program")
# Out:
# Response ok
# Good job !
# End of program
