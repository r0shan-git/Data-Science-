# %%
name="Roshan"

# %%
name
# Out:
# 'Roshan'

# %%
name.upper()
# Out:
# 'ROSHAN'

# %%
name.endswith("an")
# Out:
# True

# %%
name.endswith("aoshan")
# Out:
# False

# %%
name.lower()
# Out:
# 'roshan'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("R")
# Out:
# 1

# %%
print("  Jaishreeram  ".strip())
# Output: 'Jaishreeram'
# Out:
# Jaishreeram

# %%
s="jaishreeramroshan"
print(len(s))
# Out:
# 17

# %%
s[0:5]
# Out:
# 'jaish'

# %%
s[1:-1]
# Out:
# 'aishreeramrosha'

# %%
s[1:16]
# Out:
# 'aishreeramrosha'

# %%
s[-16:-1]
# Out:
# 'aishreeramrosha'

# %%
s[1:16]
# Out:
# 'aishreeramrosha'
