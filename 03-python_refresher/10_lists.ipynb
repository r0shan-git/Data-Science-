# %%
l=[4,54,45,6,98]

# %%
l[0]=10

# %%
l # we also chane the element of list
# Out:
# [10, 54, 45, 6, 98]

# %%
l.append(9)

# %%
l
# Out:
# [10, 54, 45, 6, 98, 9]

# %%
 l2=[5,7]

# %%
l.append(l2)

# %%
l
# Out:
# [10, 54, 45, 6, 98, 9, [5, 7]]

# %%
l.extend(l2)

# %%
l
# Out:
# [10, 54, 45, 6, 98, 9, [5, 7], 5, 7]

# %%
l.insert(6,18) #insert index 6 is 18

# %%
l
# Out:
# [10, 54, 45, 6, 98, 9, 18, [5, 7], 5, 7]

# %%
number=l.pop(0)

# %%
number
# Out:
# 10

# %%
l
# Out:
# [54, 45, 6, 98, 9, 18, [5, 7], 5, 7]

# %%
l.index(98)
# Out:
# 3

# %%
l.append(6)

# %%
l.count(6)
# Out:
# 2

# %%
l
# Out:
# [6, 9, 18, 45, 54, 98, [5, 7], 5, 7, 6]

# %%
l.count(6)
# Out:
# 2

# %%
l
# Out:
# [6, 9, 18, 45, 54, 98, [5, 7], 5, 7, 6]

# %%
l.pop(6)
# Out:
# [5, 7]

# %%
l
# Out:
# [6, 9, 18, 45, 54, 98, 5, 7, 6]

# %%
l.sort()# changes and arrange in increasing order

# %%
l
# Out:
# [5, 6, 6, 7, 9, 18, 45, 54, 98]

# %%
sorted(l)
# Out:
# [5, 6, 6, 7, 9, 18, 45, 54, 98]

# %%
newl=[2,6,1,21,6]

# %%
sorted(newl)
# Out:
# [1, 2, 6, 6, 21]

# %%
newl
# Out:
# [2, 6, 1, 21, 6]

# %%
y=[1,2,True,False,[4,7]]

# %%
y
# Out:
# [1, 2, True, False, [4, 7]]

# %%
y[4]
# Out:
# [4, 7]

# %%
y[4][1]
# Out:
# 7

# %%
list1=[4,32,12]

# %%
list2=[3,1,8]

# %%
list1+list2
# Out:
# [4, 32, 12, 3, 1, 8]

# %%
list1
# Out:
# [4, 32, 12]

# %%
list2
# Out:
# [3, 1, 8]

# %%
if 33 in list2:
    print("Yes")

# %%
3 in list2
# Out:
# True

# %%
s="Jack-shreya-shubham-kriti_slaman-akshay"

# %%
s.split("-")
# Out:
# ['Jack', 'shreya', 'shubham', 'kriti_slaman', 'akshay']
