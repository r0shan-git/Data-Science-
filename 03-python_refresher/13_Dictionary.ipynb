# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
student={"Name":"Roshan","Age":22,"Grade":"A"}

# %%
student["Name"]
# Out:
# 'Roshan'

# %%
student["Age"]
# Out:
# 22

# %%
student["Grade"]
# Out:
# 'A'

# %%
student["Name4"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 student["Name4"]
#
# KeyError: 'Name4'

# %%
r=student.get("Name4")

# %%
print(r)
# Out:
# None

# %%
student={"Name":"Roshan","Age":22,"Grade":"A"}

# %%
print(student["Age"])
# Out:
# 22

# %%
student["Age"]=67

# %%
student
# Out:
# {}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Grade'])

# %%
student.values()
# Out:
# dict_values(['Roshan', 67, 'A'])

# %%
student.items()
# Out:
# dict_items([('Name', 'Roshan'), ('Age', 67), ('Grade', 'A')])

# %%
student.update({"Name":"Harry"})

# %%
student
# Out:
# {}

# %%
student.update({"Name":"shreya","language":"python"})

# %%
student
# Out:
# {'Name': 'shreya', 'Age': 67, 'Grade': 'A', 'language': 'python'}

# %%
student.pop("Age","not found")
# Out:
# 67

# %%
student.pop("x","not found")
# Out:
# 'not found'

# %%
student
# Out:
# {}

# %%
student
# Out:
# {}

# %%
my_dict = {'a': 1, 'b': 2}

# %%
my_dict.setdefault('a',100)
# Out:
# 1

# %%
my_dict
# Out:
# {'a': 1, 'b': 2}

# %%
my_set={1,2,3,4}

# %%
my_set.clear()

# %%
print(my_set)
# Out:
# set()
