# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
name="roshan"

# %%
print("jaishreeram") #coment on the python just check
# Out:
# jaishreeram

# %%
#this is comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="4566"

# %%
b="5634"

# %%
print(a+b)
# Out:
# 45665634

# %%
int(a) + int(b) #type casting
# Out:
# 10200
