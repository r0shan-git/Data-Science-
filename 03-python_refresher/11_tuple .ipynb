# %%
e=()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
t=(95,6,7,8,9)

# %%
t
# Out:
# (95, 6, 7, 8, 9)

# %%
len(t)
# Out:
# 5

# %%
t[0]
# Out:
# 95

# %%
t[1]=35# tuple element not be change
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 t[1]=35
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Packing
person=("Roshan",22,"Engineer")
#unpacking
name,age,profession=person

# %%
name
# Out:
# 'Roshan'

# %%
age
# Out:
# 22

# %%
profession
# Out:
# 'Engineer'
