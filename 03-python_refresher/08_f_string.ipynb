# %%
s="Roshan"

# %%
s.upper()
# Out:
# 'ROSHAN'

# %%
s
# Out:
# 'Roshan'

# %%
name ="Jaishreeramroshan"
age=22
print("My name is {} and I am {} old".format(name ,age))
# Out:
# My name is Jaishreeramroshan and I am 22 old

# %%
print(f"My name is {name} and I am {age} old")
# Out:
# My name is Jaishreeramroshan and I am 22 old

# %%
pi=3.14159
print(f"pi rounded to 2 decimal places :{pi :.2f}")
# Out:
# pi rounded to 2 decimal places :3.14

# %%
print(f"{'Python':<10}")  # Left-align
print(f"{'Python':>10}")  # Right-align
print(f"{'Python':^10}")  # Center-align
# Out:
# Python
#     Python
#   Python
