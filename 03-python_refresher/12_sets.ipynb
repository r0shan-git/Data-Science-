# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b=set()

# %%
type(b)
# Out:
# set

# %%
s={1,2,3,4,5,4}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
unique_numbers=set([1,2,3,4,4,5,6,6,])
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.add(32)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 32}

# %%
s.update([63,7,727])

# %%
s
# Out:
# {1, 2, 3, 4, 5, 7, 32, 63, 727}

# %%
s.remove(66)#if element is not in set it take errror
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s.remove(66)
#
# KeyError: 66

# %%
s.discard(66)#if element in set not avialble it not give error

# %%
s
# Out:
# {1, 2, 3, 4, 5, 7, 32, 63, 727}

# %%
s.pop()
# Out:
# 2

# %%
s.remove(5)

# %%
s
# Out:
# {3, 4, 7, 32, 63, 727}

# %%
set1={1,2,3,4}
set2={3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set2
# Out:
# {3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub={1,2}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(set1)
# Out:
# True
