# %%
import json

# %%
obj={"name":"Roshan","company":"IBM","salary":450000}
s=json.dumps(obj)
type(s)
print(s)
# Out:
# {"name": "Roshan", "company": "IBM", "salary": 450000}

# %%
d=json.loads('{"name":"Roshan","company":"IBM","salary":450000}')

# %%
type(d)
# Out:
# dict

# %%
file=open("data.json","w")

# %%
json.dump(obj,file)

# %%
file.close()
