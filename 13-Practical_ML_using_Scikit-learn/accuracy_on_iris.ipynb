# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 from sklearn.ensemble import DecisionTreeClassifier
#
# ImportError: cannot import name 'DecisionTreeClassifier' from 'sklearn.ensemble' (C:\Users\ROSHAN\anaconda3\New folder\Lib\site-packages\sklearn\ensemble\__init__.py)

# %%
data=pd.read_excel("iris-train.xlsx")

# %%
data.head()

# %%
x=data.iloc[:,:-1]

# %%
x

# %%
y=data.iloc[:,-1]

# %%
y

# %%
model=RandomForestClassifier()

# %%
model.fit(x,y)

# %%
predictions=model.predict([[5.4,3,4.5,1.5]])

# %%
predictions

# %%
data=pd.read_excel("iris-test.xlsx")

# %%
data

# %%
x_test=data.iloc[:,:-1]

# %%
prediction=model.predict(x_test.values)

# %%
prediction

# %%
datatest=pd.read_excel("iris-test.xlsx")

# %%
x_test=datatest.iloc[:,:-1]

# %% [raw]
# predictions=model.predict(x_test.values)

# %%
predictions

# %%
y_test=datatest.iloc[:,:-1]

# %%
actual=y_test.values

# %%
actual

# %%
count=0
for i in range(0,len(actual)):
    if actual[i] == predictions[i]:
        count=count+1
print((count*100)/len(actual))

# %%
y_test
