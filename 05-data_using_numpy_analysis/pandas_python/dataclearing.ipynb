# %%
import pandas as pd

# %%
df=read_csv("dataclearing")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=read_csv("dataclearing")
#
# NameError: name 'read_csv' is not defined

# %%
df
