# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#     Actor                Film                      Year  Genre  \
# 0       0      Shah Rukh Khan                   Pathaan   2023
# 1       1         Salman Khan           Tiger Zinda Hai   2017
# 2       2          Aamir Khan                    Dangal   2016
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 4       4       Ranveer Singh                 Padmaavat   2018
# 5       5  Ayushmann Khurrana                 Andhadhun   2018
# 6       6       Rajkummar Rao                     Stree   2018
# 7       7      Hrithik Roshan                       War   2019
# 8       8        Akshay Kumar                Good Newwz   2019
# 9       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 10     10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 11     11       Vicky Kaushal  Uri: The Surgical Strike   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0                Action  1050         7.2
# 1                Action   565         6.0
# 2             Biography  2024         8.4
# 3               Fantasy   431         5.6
# 4            Historical   585         7.0
# 5              Thriller   111         8.3
# 6         Horror Comedy   180         7.5
# 7                Action   475         6.5
# 8                Comedy   318         7.0
# 9         Horror Comedy   266         5.9
# 10      Romantic Comedy   201         6.1
# 11               Action   342         8.2

# %%
df.sort_values("Genre")
# Out:
#     Actor                Film                      Year  Genre  \
# 2       2          Aamir Khan                    Dangal   2016
# 1       1         Salman Khan           Tiger Zinda Hai   2017
# 10     10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 4       4       Ranveer Singh                 Padmaavat   2018
# 5       5  Ayushmann Khurrana                 Andhadhun   2018
# 6       6       Rajkummar Rao                     Stree   2018
# 7       7      Hrithik Roshan                       War   2019
# 8       8        Akshay Kumar                Good Newwz   2019
# 11     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 9       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 0       0      Shah Rukh Khan                   Pathaan   2023
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 2             Biography  2024         8.4
# 1                Action   565         6.0
# 10      Romantic Comedy   201         6.1
# 4            Historical   585         7.0
# 5              Thriller   111         8.3
# 6         Horror Comedy   180         7.5
# 7                Action   475         6.5
# 8                Comedy   318         7.0
# 11               Action   342         8.2
# 3               Fantasy   431         5.6
# 9         Horror Comedy   266         5.9
# 0                Action  1050         7.2

# %%
df.sort_values("Genre",ascending=False)
# Out:
#     Actor                Film                      Year  Genre  \
# 0       0      Shah Rukh Khan                   Pathaan   2023
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 9       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 7       7      Hrithik Roshan                       War   2019
# 8       8        Akshay Kumar                Good Newwz   2019
# 11     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 4       4       Ranveer Singh                 Padmaavat   2018
# 5       5  Ayushmann Khurrana                 Andhadhun   2018
# 6       6       Rajkummar Rao                     Stree   2018
# 1       1         Salman Khan           Tiger Zinda Hai   2017
# 10     10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 2       2          Aamir Khan                    Dangal   2016
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0                Action  1050         7.2
# 3               Fantasy   431         5.6
# 9         Horror Comedy   266         5.9
# 7                Action   475         6.5
# 8                Comedy   318         7.0
# 11               Action   342         8.2
# 4            Historical   585         7.0
# 5              Thriller   111         8.3
# 6         Horror Comedy   180         7.5
# 1                Action   565         6.0
# 10      Romantic Comedy   201         6.1
# 2             Biography  2024         8.4

# %%
df2=df.sort_values(["Year","IMDb"]).copy()

# %%
df2
# Out:
#     Actor                Film                      Year  Genre  \
# 5       5  Ayushmann Khurrana                 Andhadhun   2018
# 10     10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 9       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 2       2          Aamir Khan                    Dangal   2016
# 8       8        Akshay Kumar                Good Newwz   2019
# 4       4       Ranveer Singh                 Padmaavat   2018
# 0       0      Shah Rukh Khan                   Pathaan   2023
# 6       6       Rajkummar Rao                     Stree   2018
# 1       1         Salman Khan           Tiger Zinda Hai   2017
# 11     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 7       7      Hrithik Roshan                       War   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 5              Thriller   111         8.3
# 10      Romantic Comedy   201         6.1
# 9         Horror Comedy   266         5.9
# 3               Fantasy   431         5.6
# 2             Biography  2024         8.4
# 8                Comedy   318         7.0
# 4            Historical   585         7.0
# 0                Action  1050         7.2
# 6         Horror Comedy   180         7.5
# 1                Action   565         6.0
# 11               Action   342         8.2
# 7                Action   475         6.5

# %%
df2.reset_index()
# Out:
#     index  Actor                Film                      Year  Genre  \
# 0       5      5  Ayushmann Khurrana                 Andhadhun   2018
# 1      10     10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 2       9      9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 3       3      3       Ranbir Kapoor                Brahmastra   2022
# 4       2      2          Aamir Khan                    Dangal   2016
# 5       8      8        Akshay Kumar                Good Newwz   2019
# 6       4      4       Ranveer Singh                 Padmaavat   2018
# 7       0      0      Shah Rukh Khan                   Pathaan   2023
# 8       6      6       Rajkummar Rao                     Stree   2018
# 9       1      1         Salman Khan           Tiger Zinda Hai   2017
# 10     11     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 11      7      7      Hrithik Roshan                       War   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0              Thriller   111         8.3
# 1       Romantic Comedy   201         6.1
# 2         Horror Comedy   266         5.9
# 3               Fantasy   431         5.6
# 4             Biography  2024         8.4
# 5                Comedy   318         7.0
# 6            Historical   585         7.0
# 7                Action  1050         7.2
# 8         Horror Comedy   180         7.5
# 9                Action   565         6.0
# 10               Action   342         8.2
# 11               Action   475         6.5

# %%
df2.reset_index(drop=True)
# Out:
#     Actor                Film                      Year  Genre  \
# 0       5  Ayushmann Khurrana                 Andhadhun   2018
# 1      10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 2       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 4       2          Aamir Khan                    Dangal   2016
# 5       8        Akshay Kumar                Good Newwz   2019
# 6       4       Ranveer Singh                 Padmaavat   2018
# 7       0      Shah Rukh Khan                   Pathaan   2023
# 8       6       Rajkummar Rao                     Stree   2018
# 9       1         Salman Khan           Tiger Zinda Hai   2017
# 10     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 11      7      Hrithik Roshan                       War   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0              Thriller   111         8.3
# 1       Romantic Comedy   201         6.1
# 2         Horror Comedy   266         5.9
# 3               Fantasy   431         5.6
# 4             Biography  2024         8.4
# 5                Comedy   318         7.0
# 6            Historical   585         7.0
# 7                Action  1050         7.2
# 8         Horror Comedy   180         7.5
# 9                Action   565         6.0
# 10               Action   342         8.2
# 11               Action   475         6.5

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#     Actor                Film                      Year  Genre  \
# 0       5  Ayushmann Khurrana                 Andhadhun   2018
# 1      10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 2       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 4       2          Aamir Khan                    Dangal   2016
# 5       8        Akshay Kumar                Good Newwz   2019
# 6       4       Ranveer Singh                 Padmaavat   2018
# 7       0      Shah Rukh Khan                   Pathaan   2023
# 8       6       Rajkummar Rao                     Stree   2018
# 9       1         Salman Khan           Tiger Zinda Hai   2017
# 10     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 11      7      Hrithik Roshan                       War   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0              Thriller   111         8.3
# 1       Romantic Comedy   201         6.1
# 2         Horror Comedy   266         5.9
# 3               Fantasy   431         5.6
# 4             Biography  2024         8.4
# 5                Comedy   318         7.0
# 6            Historical   585         7.0
# 7                Action  1050         7.2
# 8         Horror Comedy   180         7.5
# 9                Action   565         6.0
# 10               Action   342         8.2
# 11               Action   475         6.5

# %%
df2.sort_index()
# Out:
#     Actor                Film                      Year  Genre  \
# 0       5  Ayushmann Khurrana                 Andhadhun   2018
# 1      10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 2       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 4       2          Aamir Khan                    Dangal   2016
# 5       8        Akshay Kumar                Good Newwz   2019
# 6       4       Ranveer Singh                 Padmaavat   2018
# 7       0      Shah Rukh Khan                   Pathaan   2023
# 8       6       Rajkummar Rao                     Stree   2018
# 9       1         Salman Khan           Tiger Zinda Hai   2017
# 10     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 11      7      Hrithik Roshan                       War   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0              Thriller   111         8.3
# 1       Romantic Comedy   201         6.1
# 2         Horror Comedy   266         5.9
# 3               Fantasy   431         5.6
# 4             Biography  2024         8.4
# 5                Comedy   318         7.0
# 6            Historical   585         7.0
# 7                Action  1050         7.2
# 8         Horror Comedy   180         7.5
# 9                Action   565         6.0
# 10               Action   342         8.2
# 11               Action   475         6.5

# %%
df["Rank"]=df2["IMDb"].rank(ascending=False,method="dense")

# %%
df2
# Out:
#     Actor                Film                      Year  Genre  \
# 0       5  Ayushmann Khurrana                 Andhadhun   2018
# 1      10        Varun Dhawan     Badrinath Ki Dulhania   2017
# 2       9       Kartik Aaryan         Bhool Bhulaiyaa 2   2022
# 3       3       Ranbir Kapoor                Brahmastra   2022
# 4       2          Aamir Khan                    Dangal   2016
# 5       8        Akshay Kumar                Good Newwz   2019
# 6       4       Ranveer Singh                 Padmaavat   2018
# 7       0      Shah Rukh Khan                   Pathaan   2023
# 8       6       Rajkummar Rao                     Stree   2018
# 9       1         Salman Khan           Tiger Zinda Hai   2017
# 10     11       Vicky Kaushal  Uri: The Surgical Strike   2019
# 11      7      Hrithik Roshan                       War   2019
#
#    BoxOffice(INR Crore)  IMDb  Unnamed: 6
# 0              Thriller   111         8.3
# 1       Romantic Comedy   201         6.1
# 2         Horror Comedy   266         5.9
# 3               Fantasy   431         5.6
# 4             Biography  2024         8.4
# 5                Comedy   318         7.0
# 6            Historical   585         7.0
# 7                Action  1050         7.2
# 8         Horror Comedy   180         7.5
# 9                Action   565         6.0
# 10               Action   342         8.2
# 11               Action   475         6.5

# %%
df.columns=["Name"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.columns=["Name"]
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 1 elements
