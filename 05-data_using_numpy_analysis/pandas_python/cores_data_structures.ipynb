# %%
import pandas as np

# %%
s1=pd.Series([45,75,85,69,88,79,98,99,70,97,78])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0     45
# 1     75
# 2     85
# 3     69
# 4     88
# 5     79
# 6     98
# 7     99
# 8     70
# 9     97
# 10    78
# dtype: int64

# %%
s2=pd.Series([88,79,98,99,70,97,78],index=["Roshan","Hardik","Nikhil","VishalSumaorao","Abhishek","Anshu","Raghuvendradutt"])

# %%
s2
# Out:
# Roshan             88
# Hardik             79
# Nikhil             98
# VishalSumaorao     99
# Abhishek           70
# Anshu              97
# Raghuvendradutt    78
# dtype: int64

# %%
#we also exact the name separte
s2["Roshan"]
# Out:
# 88

# %%
import pandas as pd

s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([10 ,20, 30], index=["a","b","c"])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#DataFrame - 2D Labeled Table
import pandas as pd
data={"name":["Ram","Sita","Hanuman"],"age" :[10000,10000,100000],"Place":["Meramanme","Allwhere","Anytime"]}
df=pd.DataFrame(data)
print(df)
# Out:
#       name     age      Place
# 0      Ram   10000  Meramanme
# 1     Sita   10000   Allwhere
# 2  Hanuman  100000    Anytime

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df =pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
