# %%
import numpy as np

# %%
arr=np.array([23,21,45])

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr.astype("float64")
# Out:
# array([23., 21., 45.])

# %%
arr2=np.array([23,21,45], dtype="float32")

# %%
arr2
# Out:
# array([ 2.,  3., 21., 45.], dtype=float32)

# %%
arr2=np.array([2,3,21,45], dtype="float32")

# %%
arr2
# Out:
# array([ 2.,  3., 21., 45.], dtype=float32)

# %%
arr2.nbytes
# Out:
# 16

# %%
arr.nbytes
# Out:
# 12

# %%
arr_large=np.array([100000,2000000,3000000], dtype=np.int64)
arr_small=arr_large.astype(np.int32) #Downcasting to a smallee dtype
print(arr_small)
print(arr_large.dtype)
# Out:
# [ 100000 2000000 3000000]
# int64

# %% [raw]
# arr = np.array([1 + 2j, 3 + 4j, 5 + 6j], dtype='complex128')
# print(arr)

# %%
arr
# Out:
# array([23., 21., 45.], dtype=float32)
